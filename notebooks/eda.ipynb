# %% [markdown]
# # EDA Analysis

# %% [markdown]
# #### Importing libraries and data

# %%
import pandas as pd
rating = pd.read_csv('/home/jabez/Projects/headline_analysis/data/rating.csv')
traffic = pd.read_csv('/home/jabez/Projects/headline_analysis/data/traffic.csv')
domains = pd.read_csv('/home/jabez/Projects/headline_analysis/data/domains_location.csv')

# %% [markdown]
# #### Data Overview

# %%
# Columns info
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58356 entries, 0 to 58355
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   article_id       58356 non-null  int64
#  1   source_id        17771 non-null  object
#  2   source_name      58356 non-null  object
#  3   author           56193 non-null  object
#  4   title            58356 non-null  object
#  5   description      58346 non-null  object
#  6   url              58356 non-null  object
#  7   url_to_image     54905 non-null  object
#  8   published_at     58356 non-null  object
#  9   content          58356 non-null  object
#  10  category         58335 non-null  object
#  11  article          58356 non-null  object
#  12  title_sentiment  58356 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 5.8+ MB

# %%
rating['category']
# Out:
# 0            Monaco
# 1            Monaco
# 2        Madagascar
# 3        Madagascar
# 4        Madagascar
#             ...
# 58351          Home
# 58352          Home
# 58353          Home
# 58354          Home
# 58355          Home
# Name: category, Length: 58356, dtype: object

# %%
rating["article"].nunique()
# Out:
# 54148

# %%
# droping duplicated articles. Now each row has a unique article.
rating.drop_duplicates(subset=['article'], keep='first', inplace=True)

# %%
# 10 Websites with the most articles
rating['source_name'].value_counts().head(10)
# Out:
# source_name
# ETF Daily News        15034
# The Times of India     6962
# GlobeNewswire          5001
# Globalsecurity.org     2902
# Forbes                 2566
# Business Insider       1979
# BBC News               1955
# The Punch              1734
# ABC News               1703
# Al Jazeera English     1588
# Name: count, dtype: int64

# %%
# 10 Websites with the least articles
rating['source_name'].value_counts().tail(10)
# Out:
# source_name
# CNA                            674
# Time                           577
# Android Central                515
# Gizmodo.com                    380
# ReadWrite                      315
# Euronews                       286
# CNN                            256
# Wired                          256
# The Verge                      205
# AllAfrica - Top Africa News     18
# Name: count, dtype: int64

# %%
#top websites by globe traffic
sorted = traffic.sort_values(by='GlobalRank')
sorted['Domain'].head(10)
# Out:
# 0              google.com
# 1            facebook.com
# 2             youtube.com
# 3             twitter.com
# 4           instagram.com
# 5            linkedin.com
# 6               apple.com
# 7           microsoft.com
# 8    googletagmanager.com
# 9           wikipedia.org
# Name: Domain, dtype: object

# %%
#bottom websites by globe traffic
sorted['Domain'].tail(10)
# Out:
# 999990              eiretrip.com
# 999991      exploring-africa.com
# 999992                  hmag.com
# 999993            irishcycle.com
# 999994           keith-baker.com
# 999995                kireie.com
# 999996               mt-lock.com
# 999997             pinkwater.com
# 999998            soderhomes.com
# 999999    toyotamusicfactory.com
# Name: Domain, dtype: object

# %%
rating["article"].nunique()
# Out:
# 54148

# %%
traffic
# Out:
#         GlobalRank  TldRank                  Domain  TLD  RefSubNets   RefIPs  \
# 0                1        1              google.com  com      471274  2151358
# 1                2        2            facebook.com  com      465424  2250631
# 2                3        3             youtube.com  com      420579  1852995
# 3                4        4             twitter.com  com      404985  1757127
# 4                5        5           instagram.com  com      364746  1598085
# ...            ...      ...                     ...  ...         ...      ...
# 999995      999996   485324              kireie.com  com         222      280
# 999996      999997   485325             mt-lock.com  com         222      280
# 999997      999998   485326           pinkwater.com  com         222      280
# 999998      999999   485327          soderhomes.com  com         222      280
# 999999     1000000   485328  toyotamusicfactory.com  com         222      280
#
#                     IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  \
# 0                   google.com     com               1            1
# 1                 facebook.com     com               2            2
# 2                  youtube.com     com               3            3
# 3                  twitter.com     com               4            4
# 4                instagram.com     com               5            5
# ...                        ...     ...             ...          ...
# 999995              kireie.com     com              -1           -1
# 999996             mt-lock.com     com          952633       461429
# 999997           pinkwater.com     com              -1           -1
# 999998          soderhomes.com     com              -1           -1
# 999999  toyotamusicfactory.com     com          973201       471949
#
#         PrevRefSubNets  PrevRefIPs
# 0               471248     2147402
# 1               465297     2247135
# 2               420483     1848940
# 3               404998     1753939
# 4               364618     1594892
# ...                ...         ...
# 999995              -1          -1
# 999996             232         284
# 999997              -1          -1
# 999998              -1          -1
# 999999             228         284
#
# [1000000 rows x 12 columns]

# %%
rating.sort_values(by='source_name')
# Out:
#        article_id source_id source_name  \
# 7374        18460  abc-news    ABC News
# 23123      191917  abc-news    ABC News
# 12320       66081  abc-news    ABC News
# 8029        20755  abc-news    ABC News
# 12315       66022  abc-news    ABC News
# ...           ...       ...         ...
# 7085        16801     wired       Wired
# 27314      228478     wired       Wired
# 21626      175047     wired       Wired
# 935         87189     wired       Wired
# 9802        32812     wired       Wired
#
#                                                   author  \
# 7374                                      Kelly McCarthy
# 23123        Quinn Owen, Mireya Villarreal, James Scholz
# 12320                                  Alexandra Hutzler
# 8029   Katherine Carroll, Arielle Schwartz, Emily Sha...
# 12315                JONATHAN J. COOPER Associated Press
# ...                                                  ...
# 7085                                         Kate Knibbs
# 27314                                   Scott Gilbertson
# 21626                                       Ramin Skibba
# 935                                          Saqib Rahim
# 9802                                    Eric Ravenscraft
#
#                                                    title  \
# 7374   birkenstock goes public on new york stock exch...
# 23123  Fighting against fentanyl: How border agents a...
# 12320  house to consider censure resolution against t...
# 8029   grandson recounts seeing graphic video of belo...
# 12315  trump campaign says he raised more than $45m i...
# ...                                                  ...
# 7085            ai watermarks are no match for attackers
# 27314  23 Best Black Friday Deals on Outdoor Gear (20...
# 21626  The Euclid Space Telescope’s Spectacular First...
# 935    hydro dams are struggling to handle the world’...
# 9802   steelseries alias pro review: a newbie-friendl...
#
#                                              description  \
# 7374   Birkenstock took its footwear company public a...
# 23123  Senior government officials are concerned that...
# 12320  The House of Representatives on Wednesday will...
# 8029   Yoav Shimoni, 24, recounted to ABC News witnes...
# 12315  Donald Trump’s campaign says it raised more th...
# ...                                                  ...
# 7085   Researchers say that it's too easy to evade cu...
# 27314  Check out REI, one of our favorite outdoor gea...
# 21626  Images from the European Space Agency’s newest...
# 935    Climate change is robbing some hydro dams of w...
# 9802   This XLR microphone is the perfect stepping st...
#
#                                                      url  \
# 7374   https://abcnews.go.com/GMA/Style/birkenstock-p...
# 23123  https://abcnews.go.com/Politics/fighting-fenta...
# 12320  https://abcnews.go.com/Politics/house-censure-...
# 8029   https://abcnews.go.com/International/grandson-...
# 12315  https://abcnews.go.com/Politics/wireStory/trum...
# ...                                                  ...
# 7085   https://www.wired.com/story/artificial-intelli...
# 27314  https://www.wired.com/story/black-friday-outdo...
# 21626  https://www.wired.com/story/the-euclid-space-t...
# 935    https://www.wired.com/story/hydro-dams-climate...
# 9802   https://www.wired.com/review/steelseries-alias...
#
#                                             url_to_image  \
# 7374   https://i.abcnewsfe.com/a/d2942c0b-1891-41f7-9...
# 23123  https://i.abcnewsfe.com/a/8cfab2f4-5b89-4bc6-a...
# 12320  https://i.abcnewsfe.com/a/d8a803cd-fe53-432c-a...
# 8029   https://i.abcnewsfe.com/a/f196f71e-5b04-4205-8...
# 12315  https://i.abcnewsfe.com/a/fde6f62e-1d4f-4482-8...
# ...                                                  ...
# 7085   https://media.wired.com/photos/651b4a6acbda616...
# 27314  https://media.wired.com/photos/654dc3428d8131a...
# 21626  https://media.wired.com/photos/654971d21147e00...
# 935    https://media.wired.com/photos/65276176b58ef6b...
# 9802   https://media.wired.com/photos/651b219882e82f1...
#
#                      published_at  \
# 7374   2023-10-12 20:56:17.000000
# 23123         2023-11-07 16:58:03
# 12320  2023-11-01 21:09:27.000000
# 8029   2023-10-13 16:53:51.000000
# 12315  2023-10-05 02:36:12.000000
# ...                           ...
# 7085   2023-10-03 10:00:00.000000
# 27314         2023-11-10 12:00:00
# 21626         2023-11-07 13:38:37
# 935    2023-10-12 11:00:00.000000
# 9802   2023-10-03 14:00:00.000000
#
#                                                  content  category  \
# 7374   Birkenstock took a big step forward on Wall St...    Europe
# 23123  NOGALES, Arizona -- Senior government official...    Israel
# 12320  The House on Wednesday will weigh two censure ...   Georgia
# 8029   Yoav Shimoni opened up to ABC News about the t...  Facebook
# 12315  Donald Trumps campaign said Wednesday it raise...   Georgia
# ...                                                  ...       ...
# 7085   Soheil Feizi considers himself an optimistic p...     world
# 27314  Black Friday is traditionally the season when ...      News
# 21626  Scientists leading the European Space Agencys ...   Science
# 935    For BC Hydro, which serves 95 percent of Briti...   Namibia
# 9802   For streamers, podcasters, and basically anyon...     Space
#
#                                                  article title_sentiment
# 7374   birkenstock took a big step forward on wall st...         Neutral
# 23123  NOGALES, Arizona --Senior government officials...         Neutral
# 12320  house democrats on wednesday, aided by some re...         Neutral
# 8029   yoav shimoni opened up to abc news about the t...        Negative
# 12315  donald trump’s campaign said wednesday it rais...         Neutral
# ...                                                  ...             ...
# 7085   soheil feizi considershimself an optimistic pe...        Negative
# 27314  Black Friday istraditionally the season when y...        Positive
# 21626  Scientists leading theEuropean Space Agency’sE...         Neutral
# 935    it’s been oneof thewettest yearsin california ...        Negative
# 9802   for streamers, podcasters,and basically anyone...        Positive
#
# [58356 rows x 13 columns]

# %%
domains
# Out:
#       SourceCommonName location    Country
# 0           00221.info       SG    Senegal
# 1            01net.com       FR     France
# 2             01net.it       IT      Italy
# 3          0223.com.ar       AR  Argentina
# 4         022china.com       CH      China
# ...                ...      ...        ...
# 37797      zz.diena.lv       LG     Latvia
# 37798      zz.fjnet.cn       CH      China
# 37799        zz.mnw.cn       CH      China
# 37800           zz7.it       IT      Italy
# 37801    zznews.gov.cn       CH      China
#
# [37802 rows x 3 columns]

# %%
df
